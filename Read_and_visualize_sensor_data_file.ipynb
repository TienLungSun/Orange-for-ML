# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a0c3b0ec-18cd-4d82-b714-beafa72054ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0c3b0ec-18cd-4d82-b714-beafa72054ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MotionData110000_001001_2018_09_14_09_39_26.csv to MotionData110000_001001_2018_09_14_09_39_26.csv

# %%
fnameLst = list(uploaded.keys())
fname = fnameLst[0]
print(fname)
# Out:
# MotionData110000_001001_2018_09_14_09_39_26.csv

# %%
import pandas as pd
df=pd.read_csv(fname)

# %%
df.head(5)
# Out:
#            time   AccX   AccY   AccZ   EulerX   EulerY   EulerZ
# 0  09:39:26:180  -0.04  -0.03  -0.30  -106.05   -66.92     2.16
# 1  09:39:26:212  -0.04  -0.03  -0.30  -106.05   -66.92     2.16
# 2  09:39:26:246  -0.01   0.06  -0.26  -106.62   -69.60     1.38
# 3  09:39:26:279  -0.01   0.06  -0.26  -106.62   -69.60     1.38
# 4  09:39:26:312  -0.01  -0.04  -0.33  -106.29   -71.47    -0.65

# %%
df.columns
# Out:
# Index(['time', ' AccX', ' AccY', ' AccZ', ' EulerX', ' EulerY', ' EulerZ'], dtype='object')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 9))
plt.plot(df[' AccX'], color="red")
plt.plot(df[' AccY'], color="green")
plt.plot(df[' AccZ'], color="blue")
plt.legend(['AccX', 'AccY', 'AccZ'])
plt.show()
